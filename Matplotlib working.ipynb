# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8C2A-364F
#
#  Directory of C:\Users\Safeer\My Drive\Git_Project\Zero-to-Mastery-in-Machine-Learning
#
# 01/07/2023  01:32 PM    <DIR>          .
# 01/07/2023  01:32 PM    <DIR>          ..
# 12/21/2022  09:45 PM                66 .gitattributes
# 01/07/2023  01:32 PM    <DIR>          .ipynb_checkpoints
# 07/17/2022  03:59 AM            11,328 13.1 heart-disease.csv
# 01/07/2023  03:44 AM           789,357 Matplotlib working.ipynb
# 12/21/2022  09:45 PM                86 README.md
# 01/06/2023  10:59 PM            28,877 temporary PLOT saved.png
#                5 File(s)        829,714 bytes
#                3 Dir(s)  200,975,732,736 bytes free

# %%
heart_dis = pd.read_csv("13.1 heart-disease.csv")
heart_dis
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
arr = np.array([[1,2,3,4,5,6],[11,22,33,44,55,66]])
arr
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [11, 22, 33, 44, 55, 66]])

# %%
plt.plot();

# %%
plt.plot(arr[0],arr[1])

# %%
fig , ax = plt.subplots()
ax.plot(arr[0],arr[1]//2,   'bo');

# %%
fig,ax = plt.subplots(figsize =(15,5))
ax.plot(heart_dis['age'])
plt.show()

# %%
data = [[2 , 3 ,5, 6, 8, 9], [ 11 , 22, 55, 66, 99,77 ]]

fig , ax = plt.subplots(figsize = (10,5))

ax.plot(data[0],data[1] )

ax.set(title='matplotelib practice',
      xlabel='linear number',
      ylabel='incremental data',
      )

fig.savefig ("temporary PLOT saved.png")

# %%
z_ax = np.arange (0,10)
data = np.random.randint (10, size = 10)
print (data)

fig , ax = plt.subplots(figsize = (15,5))

ax.plot (z_ax, np.exp (data))
# Out:
# [1 7 0 4 5 5 6 5 7 0]

# %%
fig , ax = plt.subplots(figsize = (15,5))
ax.scatter (z_ax,z_ax**2 )

# %%
items_dic =    {
    'peanut' : 15,
    'cocunet': 25,
    'almond' : 35
}

#print (items_dic.keys(), items_dic.values())

fig, ax = plt.subplots(figsize = (5,5))

ax.bar (items_dic.keys(), items_dic.values(), width= .15)
ax.set(title="Items lists", ylabel= " Price per Kg in USD")
plt.show()

# %%
data = np.random.randn(100)
fig, ax = plt.subplots()
ax.hist (data)
# Out:
# (array([ 1.,  0.,  2.,  3.,  9., 22., 21., 20., 17.,  5.]),
#  array([-3.59863143, -3.04679701, -2.49496259, -1.94312816, -1.39129374,
#         -0.83945932, -0.28762489,  0.26420953,  0.81604396,  1.36787838,
#          1.9197128 ]),
#  <BarContainer object of 10 artists>)

# %%
x = plt.hist (data, bins = 2)

# %%
(np.array(x))[0]
# Out:
# C:\Users\Safeer\AppData\Local\Temp\ipykernel_8724\1322370651.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   (np.array(x))[0]
# array([15., 85.])

# %%
fig, ax = plt.subplots(
                        nrows = 1,
                        ncols = 2,
                        figsize = (15,5)
                      )
ax[0].plot (data, data**2);
ax[0].set (title = "power of natural numbers", xlabel = 'values of naormal distribution', ylabel = 'power of normal dist')

ax[1].scatter (x = np.arange(-5,5,.1) , y = data)

# %%
list(range(-5,5,2))
# Out:
# [-5, -3, -1, 1, 3]

# %%
np.arange(-5,5,.1)
# Out:
# array([-5.00000000e+00, -4.90000000e+00, -4.80000000e+00, -4.70000000e+00,
#        -4.60000000e+00, -4.50000000e+00, -4.40000000e+00, -4.30000000e+00,
#        -4.20000000e+00, -4.10000000e+00, -4.00000000e+00, -3.90000000e+00,
#        -3.80000000e+00, -3.70000000e+00, -3.60000000e+00, -3.50000000e+00,
#        -3.40000000e+00, -3.30000000e+00, -3.20000000e+00, -3.10000000e+00,
#        -3.00000000e+00, -2.90000000e+00, -2.80000000e+00, -2.70000000e+00,
#        -2.60000000e+00, -2.50000000e+00, -2.40000000e+00, -2.30000000e+00,
#        -2.20000000e+00, -2.10000000e+00, -2.00000000e+00, -1.90000000e+00,
#        -1.80000000e+00, -1.70000000e+00, -1.60000000e+00, -1.50000000e+00,
#        -1.40000000e+00, -1.30000000e+00, -1.20000000e+00, -1.10000000e+00,
#        -1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
# ...

# %%
heart_dis.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_dis.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_dis['date'] = pd.date_range('1/1/2022', periods= len (heart_dis))
heart_dis
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target       date
# 0        0   0     1       1 2022-01-01
# ...

# %%
heart_dis.plot.scatter ( y = ['age','trestbps'], x =['date','date'] );
#heart_dis.plot (kind = 'line', y = 'trestbps', );

plt.xlabel(" number of samples")
plt.ylabel(" Age ", size = 5)
plt.title ("And and Trestbps", size = 15)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
list( (0,100))
# Out:
# [0, 100]

# %%
heart_dis.plot (kind = 'scatter', y = ['chol' , 'oldpeak'], x = ['date','date'], figsize= (15,5))
# Out:
# <AxesSubplot:xlabel='[date, date]', ylabel='[chol, oldpeak]'>

# %%
heart_dis['restecg'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_dis.plot.scatter(y = 'restecg' , x = 'date')
# Out:
# <AxesSubplot:xlabel='date', ylabel='restecg'>

# %%
heart_dis[heart_dis['restecg'] == 2]['date']
# Out:
# 144   2022-05-25
# 266   2022-09-24
# 289   2022-10-17
# 291   2022-10-19
# Name: date, dtype: datetime64[ns]

# %%
heart_dis['restecg'].plot.box()
# Out:
# <AxesSubplot:>

# %%
heart_dis.plot.bar( x= 'date',subplots = True, figsize = (15,35))
# Out:
# array([<AxesSubplot:title={'center':'age'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'sex'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'cp'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'trestbps'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'chol'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'fbs'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'restecg'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'thalach'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'exang'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'oldpeak'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'slope'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'ca'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'thal'}, xlabel='date'>,
#        <AxesSubplot:title={'center':'target'}, xlabel='date'>],
#       dtype=object)

# %%
plt.style.use('seaborn-white')
heart_dis.plot.scatter(x='age', y = 'oldpeak' , c = 'target')
# Out:
# <AxesSubplot:xlabel='age', ylabel='oldpeak'>

# %%
fig, ax = plt.subplots(nrows=2,ncols=1,figsize = (10,10))

scatter = ax[0].scatter (x = heart_dis.age, 
                         y = heart_dis.chol, 
                         c = heart_dis.target)

ax[0].set (
            title = 'Heart Disease and cholesterol Levels',
            xlabel = 'Age',
            ylabel = ' cholesterol Levels and Heart Disease',
            xlim = (0,100)
            ) 

ax[0].legend (*scatter.legend_elements(), title = 'Target')

ax[0].axhline(y = heart_dis.chol.mean(),
                       linestyle = '--')

# Second plot 
ax[1].scatter (
                y = heart_dis['thal'],
                x = heart_dis['age'],
                c = heart_dis.target
)

ax[1].set (title = 'Heart Disease and Thal level',
            xlabel = 'Age',
            ylabel = 'level',
            xlim = (0,100))

ax[1].legend (*scatter.legend_elements(), title = 'Target')

ax[1].axhline (y = heart_dis.thal.mean(), linestyle = '--')

fig.suptitle ('Heart Disease Analysis', fontsize = 16);
