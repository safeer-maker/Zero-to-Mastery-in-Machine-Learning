# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8C2A-364F
#
#  Directory of C:\Users\Safeer\My Drive\Git_Project\Zero-to-Mastery-in-Machine-Learning
#
# 12/25/2022  09:00 PM    <DIR>          .
# 12/25/2022  09:00 PM    <DIR>          ..
# 12/21/2022  09:45 PM                66 .gitattributes
# 12/25/2022  09:00 PM    <DIR>          .ipynb_checkpoints
# 07/17/2022  03:59 AM            11,328 13.1 heart-disease.csv
# 12/22/2022  08:59 PM           216,080 Matplotlib working.ipynb
# 12/21/2022  09:45 PM                86 README.md
# 12/22/2022  08:18 PM            28,877 temporary PLOT saved.png
#                5 File(s)        256,437 bytes
#                3 Dir(s)  226,158,821,376 bytes free

# %%
heart_dis = pd.read_csv("13.1 heart-disease.csv")
heart_dis
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
arr = np.array([[1,2,3,4,5,6],[11,22,33,44,55,66]])
arr
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [11, 22, 33, 44, 55, 66]])

# %%
plt.plot();

# %%
plt.plot(arr[0],arr[1])

# %%
fig , ax = plt.subplots()
ax.plot(arr[0],arr[1]//2,   'bo');

# %%
fig,ax = plt.subplots()
ax.plot(heart_dis['age'])
plt.show()

# %%
data = [[2 , 3 ,5, 6, 8, 9], [ 11 , 22, 55, 66, 99,77 ]]

fig , ax = plt.subplots(figsize = (10,5))

ax.plot(data[0],data[1] )

ax.set(title='matplotelib practice',
      xlabel='linear number',
      ylabel='incremental data',
      )

fig.savefig ("temporary PLOT saved.png")

# %%
z_ax = np.arange (0,10)
data = np.random.randint (10, size = 10)
print (data)

fig , ax = plt.subplots(figsize = (15,5))

ax.plot (z_ax, np.exp (data))
# Out:
# [4 5 8 6 4 1 8 3 3 9]

# %%
fig , ax = plt.subplots(figsize = (15,5))
ax.scatter (z_ax,z_ax**2 )

# %%
items_dic =    {
    'peanut' : 15,
    'cocunet': 25,
    'almond' : 35
}

#print (items_dic.keys(), items_dic.values())

fig, ax = plt.subplots(figsize = (5,5))

ax.bar (items_dic.keys(), items_dic.values(), width= .15)
ax.set(title="Items lists", ylabel= " Price per Kg in USD")
plt.show()

# %%
data = np.random.randn(500)
fig, ax = plt.subplots()
ax.hist (data)
# Out:
# (array([  2.,   7.,  34.,  75., 112., 127.,  89.,  34.,  14.,   6.]),
#  array([-3.2032792 , -2.5681281 , -1.93297701, -1.29782591, -0.66267482,
#         -0.02752372,  0.60762737,  1.24277847,  1.87792956,  2.51308066,
#          3.14823175]),
#  <BarContainer object of 10 artists>)

# %%
x = plt.hist (data, bins = 2)

# %%
(np.array(x))[0]
# Out:
# C:\Users\Safeer\AppData\Local\Temp\ipykernel_6036\1322370651.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   (np.array(x))[0]
# array([230., 270.])
